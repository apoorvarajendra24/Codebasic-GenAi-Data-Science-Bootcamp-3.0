# %%
5/2
# Out:
# 2.5

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv('datasets/fact_bookings_clean.csv')
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT15        16558     27-04-22      1/5/2022
# 2        May012216558RT16        16558     1/5/2022      1/5/2022
# 3        May012216558RT17        16558     28-04-22      1/5/2022
# 4        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22      31-07-22
# 134569   Jul312217564RT46        17564     29-07-22      31-07-22
# 134570   Jul312217564RT48        17564     30-07-22      31-07-22
# 134571   Jul312217564RT49        17564     29-07-22      31-07-22
# 134572  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels = pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_aggr_bookings = pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_aggr_bookings['occupancy_percentage %'] = round(((df_aggr_bookings['successful_bookings'] / df_aggr_bookings['capacity']) * 100),2)
df_aggr_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy_percentage %
# ...

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_date.dtypes
# Out:
# date        str
# mmm yy      str
# week no     str
# day_type    str
# dtype: object

# %%
df_date['day_type'] = df_date['day_type'].replace('weekeday','weekday')
df_date
# Out:
#          date  mmm yy week no day_type
# 0   01-May-22  May 22    W 19  weekend
# 1   02-May-22  May 22    W 19  weekday
# 2   03-May-22  May 22    W 19  weekday
# 3   04-May-22  May 22    W 19  weekday
# 4   05-May-22  May 22    W 19  weekday
# ..        ...     ...     ...      ...
# 87  27-Jul-22  Jul 22    W 31  weekday
# 88  28-Jul-22  Jul 22    W 31  weekday
# 89  29-Jul-22  Jul 22    W 31  weekday
# 90  30-Jul-22  Jul 22    W 31  weekend
# 91  31-Jul-22  Jul 22    W 32  weekend
#
# [92 rows x 4 columns]

# %%
df_date['date'] = pd.to_datetime(df_date['date'])
df_date
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5600\2310970186.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date['date'] = pd.to_datetime(df_date['date'])
#          date  mmm yy week no day_type
# 0  2022-05-01  May 22    W 19  weekend
# 1  2022-05-02  May 22    W 19  weekday
# 2  2022-05-03  May 22    W 19  weekday
# 3  2022-05-04  May 22    W 19  weekday
# 4  2022-05-05  May 22    W 19  weekday
# ..        ...     ...     ...      ...
# 87 2022-07-27  Jul 22    W 31  weekday
# 88 2022-07-28  Jul 22    W 31  weekday
# 89 2022-07-29  Jul 22    W 31  weekday
# 90 2022-07-30  Jul 22    W 31  weekend
# 91 2022-07-31  Jul 22    W 32  weekend
#
# [92 rows x 4 columns]

# %%
df_date['month'] = df_date['date'].dt.strftime('%b')
df_date['year'] = df_date['date'].dt.year
df_date['week_no'] = 'W ' + df_date['date'].dt.isocalendar().week.astype(str)
df_date
# Out:
#          date  mmm yy week no day_type month  year week_no
# 0  2022-05-01  May 22    W 19  weekend   May  2022    W 17
# 1  2022-05-02  May 22    W 19  weekday   May  2022    W 18
# 2  2022-05-03  May 22    W 19  weekday   May  2022    W 18
# 3  2022-05-04  May 22    W 19  weekday   May  2022    W 18
# 4  2022-05-05  May 22    W 19  weekday   May  2022    W 18
# ..        ...     ...     ...      ...   ...   ...     ...
# 87 2022-07-27  Jul 22    W 31  weekday   Jul  2022    W 30
# 88 2022-07-28  Jul 22    W 31  weekday   Jul  2022    W 30
# 89 2022-07-29  Jul 22    W 31  weekday   Jul  2022    W 30
# 90 2022-07-30  Jul 22    W 31  weekend   Jul  2022    W 30
# 91 2022-07-31  Jul 22    W 32  weekend   Jul  2022    W 30
#
# [92 rows x 7 columns]

# %%
df_date
# Out:
#          date  mmm yy week no day_type month  year week_no
# 0  2022-05-01  May 22    W 19  weekend   May  2022    W 17
# 1  2022-05-02  May 22    W 19  weekday   May  2022    W 18
# 2  2022-05-03  May 22    W 19  weekday   May  2022    W 18
# 3  2022-05-04  May 22    W 19  weekday   May  2022    W 18
# 4  2022-05-05  May 22    W 19  weekday   May  2022    W 18
# ..        ...     ...     ...      ...   ...   ...     ...
# 87 2022-07-27  Jul 22    W 31  weekday   Jul  2022    W 30
# 88 2022-07-28  Jul 22    W 31  weekday   Jul  2022    W 30
# 89 2022-07-29  Jul 22    W 31  weekday   Jul  2022    W 30
# 90 2022-07-30  Jul 22    W 31  weekend   Jul  2022    W 30
# 91 2022-07-31  Jul 22    W 32  weekend   Jul  2022    W 30
#
# [92 rows x 7 columns]

# %%
df_date.drop('mmm yy', axis=1, inplace=True)

# %%
df_date.to_csv('datasets/dim_dates_clean.csv')

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential
