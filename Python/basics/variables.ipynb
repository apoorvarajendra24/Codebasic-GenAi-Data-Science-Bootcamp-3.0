# %%
# Variable is a container to store data.
can="soda"
print(can)
print(type(can))
# Out:
# soda
# <class 'str'>

# %%
# types of variable
pizza = 100
samosa = 20
ice_cream = 35.5

total_bill = pizza + samosa + ice_cream
print(total_bill)
print(type(total_bill))
print(type(pizza))
print(type(samosa))
print(type(ice_cream))
# Out:
# 155.5
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
above_threshold = total_bill > 200
print(above_threshold)
# Out:
# False

# %%
foo="biryani"
foo
# Out:
# 'biryani'

# %%
fii=foo
fii
# Out:
# 'biryani'

# %%
id(foo)
# Out:
# 1862709608736

# %%
id(fii)
# Out:
# 1862709608736

# %%
ans= id(foo) == id(fii)
ans
# variable fii is pointing to the identifier (say address as in c/java) 
# of variable foo where the value "biryani' is stored.
# Out:
# True

# %%
fii="aloo bonda"
id(fii)
# Out:
# 1862710382064

# %%
ans = id(fii) == id(foo)
ans
# Out:
# False

# %%
True = 5
# Out:
#   Cell In[14], line 1
#     True = 5
#     ^
# SyntaxError: cannot assign to True

# %%
$anb = "abcd"
# Out:
#   Cell In[16], line 1
#     $anb = "abcd"
#     ^
# SyntaxError: invalid syntax

# %%
4bit=45.4
# Out:
#   Cell In[17], line 1
#     4bit=45.4
#     ^
# SyntaxError: invalid decimal literal

# %%
name_person='ben'
name_person
# Out:
# 'ben'

# %%
value5 = 54
value5
# Out:
# 54
