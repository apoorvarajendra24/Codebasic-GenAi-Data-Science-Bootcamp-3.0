# %%
first = 'tanvi'
last = 'sharma'

# %%
full_name = first + " " + last
full_name
# Out:
# 'tanvi sharma'

# %%
name = f"{first} {last}"
name
# Out:
# 'tanvi sharma'

# %%
age = 30

info = f'{first} {last} is {age} year old.'
info
# Out:
# 'tanvi sharma is 30 year old.'

# %%
print(name)
print(id(name))
# Out:
# tanvi sharma
# 3033446236784

# %%
#indexing
#character at index 0
print(name[0])
print(name[0:4])
print(name[6:])
print(name[:-1])
print(name[-2])
# Out:
# t
# tanv
# sharma
# tanvi sharm
# m

# %%
print(name[12])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(name[12])
#
# IndexError: string index out of range

# %%
len(name)
# Out:
# 12

# %%
print(name[:len(name)])
# Out:
# tanvi sharma

# %%
name[0] = "s"
name

# String objects are immutable that is once created cannot be changed.
# therefore they do not support assignment operation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 name[0] = "s"
#       2 name
#
# TypeError: 'str' object does not support item assignment

# %%
#ressignment is allowed.
name = "sanvi sharma"
name

# here we are not modifying the old string.
# Creating a new string object and making name point to this object.
# Out:
# 'sanvi sharma'

# %%
id(name)
# Out:
# 3033446242544

# %%
# String interning
# python reuses strings internally. sometime it happens sometime it does not

a = 'hello'
b = 'hello'
print(id(a)==id(b))

# both variable pointing to the same object.
# Out:
# True

# %%
recipe = "Boil water, add pasta, cook for 10 minutes, drain and serve."
recipe
# Out:
# 'Boil water, add pasta, cook for 10 minutes, drain and serve.'

# %%
"pasta" in recipe
# Out:
# True

# %%
"milk" in recipe
# Out:
# False

# %%
#find where pasta is in string
recipe.find("pasta")
# Out:
# 16

# %%
s = "patient was charged $100 for lab test"
s
# Out:
# 'patient was charged $100 for lab test'

# %%
# shows all the function which can be used over string
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
#this will create a new string so we need to re assign it back to s
# to see the changes
s = s.replace("$100","$16")
s
# Out:
# 'patient was charged $16 for lab test'

# %%
s
# Out:
# 'patient was charged $16 for lab test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARGED $16 FOR LAB TEST'

# %%
s.lower()
# Out:
# 'patient was charged $16 for lab test'

# %%
'4tanvi9'.isdigit()
# Out:
# False

# %%
"34tabcu".isalnum()
# Out:
# True

# %%
s.index("$16")
# Out:
# 20

# %%
age = 25
text = "My age is : "
con_txt = text + str(age)
con_txt
# Out:
# 'My age is : 25'

# %%
tickers = "AAPL,GOOGL,TCS,NVDS,RIL"
sep_tickers = tickers.split(",",maxsplit=2)  # max 2 splits then combine all the string
sep_tickers
# Out:
# ['AAPL', 'GOOGL', 'TCS,NVDS,RIL']

# %%
data = " hey, how are you? are you coming t the movie today?  "
data
# Out:
# ' hey, how are you? are you coming t the movie today?  '

# %%
data.strip()
# Out:
# 'hey, how are you? are you coming t the movie today?'

# %%
file_name = "report.pdf"
if file_name.endswith(".pdf"):
    print("yes")
else:
    print("no")
# Out:
# yes
