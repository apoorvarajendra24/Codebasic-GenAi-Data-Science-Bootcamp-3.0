# %%
# Calculate Area of Triangle
base = 10
height = 5

area = (base * height)/2
area
# Out:
# 25.0

# %%
type(area)
# Out:
# float

# %%
# Operations
x = 4
y = 10

# %%
#addition
x+y
# Out:
# 14

# %%
#subtraction
x-y
# Out:
# -6

# %%
#division
x/y
# Out:
# 0.4

# %%
# division print only integer part --> gives quotient
x//y
# Out:
# 0

# %%
#multiplication
x*y
# Out:
# 40

# %%
#modulus --> gives remainder
x%y
# Out:
# 4

# %%
(x,y)
# Out:
# (4, 10)

# %%
#power to
x**y
# Out:
# 1048576

# %%
ab=2.4e5
ab
# Out:
# 240000.0

# %%
# 1e4--> 1 raised to power 4 e--> power function
a=1e4
a
# Out:
# 10000.0

# %%
# 2.3 raised to power -3 --> 2.3/10 power 3
b=2.3e-3
b
# Out:
# 0.0023

# %%
 food = 200.34
 rent = 15e4
 other = 2000.89

 total = food + rent + other
 print(total)
# Out:
# 152201.23

# %%
round(total)
# Out:
# 152201

# %%
income = 71000.73829
expenses = 20000.4534
savings = income - expenses
savings
# Out:
# 51000.284889999995

# %%
food = "120.34"
rent = "403.55"
total = food + rent   # concatenation
total
# Out:
# '120.34403.55'

# %%
#type conversion
total = float(food) + float(rent)
total
# Out:
# 523.89

# %%
round(savings,3)
# Out:
# 51000.285

# %%
import math
x = 16
math.sqrt(x)
# Out:
# 4.0

# %%
#floor value
math.floor(3.7)
# Out:
# 3

# %%
#ceil value
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
#Area of circle
radius = 12
area_circle = math.pi * (radius**2)
area_circle
# Out:
# 452.3893421169302

# %%
# show how integer are stored in binary
format(10,'b')
# Out:
# '1010'
