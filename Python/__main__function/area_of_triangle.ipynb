# %%
import triangle

print("Inside area file..")
print(triangle.calculate_triangle_area(10,5))
# Out:
# Inside area file..
# Value of __name__ : triangle
# 25.0

# %%
print(__name__)
# Out:
# __main__
