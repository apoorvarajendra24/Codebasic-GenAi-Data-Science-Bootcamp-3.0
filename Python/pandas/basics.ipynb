# %%
import csv

# %%
def calculate_rating_stats(data,industry=None):
    rating = []
    for row in data:
        if row[3]!= 'NULL' and (not industry or row[1]==industry):
            rating.append(float(row[3]))
    max_rating = max(rating)
    min_rating = min(rating)
    avg_rating = sum(rating) / len(rating)
    return max_rating, min_rating, avg_rating

# %%
calculate_rating_stats(data)
# Out:
# [8.3, 7.0, 6.8, 7.9, 6.8, 9.3, 8.6, 8.0, 8.5, 7.9, 8.6, 7.8, 9.2, 9.0, 9.0, 8.2, 8.5, 8.4, 8.4, 6.9, 7.8, 8.0, 8.4, 7.4, 7.2, 8.3, 8.1, 8.1, 8.3, 8.1, 1.9, 8.4, 8.4, 7.6, 8.0, 8.0]
# (9.3, 1.9, 7.919444444444445)

# %%
with open("movies.csv") as f:
    data = list(csv.reader(f))
    print(data)
    header = data[0]
    data = data[1:]
data
# Out:
# [['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget', 'revenue', 'unit', 'currency', 'language'], ['Pather Panchali', 'Bollywood', '1955', '8.3', 'Government of West Bengal', '70000', '100000', 'Thousands', 'INR', 'Bengali'], ['Doctor Strange in the Multiverse of Madness', 'Hollywood', '2022', '7', 'Marvel Studios', '200', '954.8', 'Millions', 'USD', 'English'], ['Thor: The Dark World ', 'Hollywood', '2013', '6.8', 'Marvel Studios', '165', '644.8', 'Millions', 'USD', 'English'], ['Thor: Ragnarok ', 'Hollywood', '2017', '7.9', 'Marvel Studios', '180', '854', 'Millions', 'USD', 'English'], ['Thor: Love and Thunder ', 'Hollywood', '2022', '6.8', 'Marvel Studios', '250', '670', 'Millions', 'USD', 'English'], ['The Shawshank Redemption', 'Hollywood', '1994', '9.3', 'Castle Rock Entertainment', '25', '73.3', 'Millions', 'USD', 'English'], ['Interstellar', 'Hollywood', '2014', '8.6', 'Warner Bros. Pictures', '165', '701.8', 'Millions', 'USD', 'English'], ['The Pursuit of
# ...

# %%
max_rating, min_rating, avg_rating = calculate_rating_stats(data)
print(f"All records: \nMIN rating: {min_rating}\nMAX rating: {max_rating}\nAVG rating: {avg_rating}")

max_rating, min_rating, avg_rating = calculate_rating_stats(data,industry="Bollywood")
print(f"BOLLYWOOD records: \nMIN rating: {min_rating}\nMAX rating: {max_rating}\nAVG rating: {avg_rating}")

max_rating, min_rating, avg_rating = calculate_rating_stats(data,industry="Hollywood")
print(f"HOLLYWOOD records: \nMIN rating: {min_rating}\nMAX rating: {max_rating}\nAVG rating: {avg_rating}")
# Out:
# All records:
# MIN rating: 1.9
# MAX rating: 9.3
# AVG rating: 7.919444444444445
# BOLLYWOOD records:
# MIN rating: 1.9
# MAX rating: 8.4
# AVG rating: 7.65625
# HOLLYWOOD records:
# MIN rating: 6.8
# MAX rating: 9.3
# AVG rating: 8.129999999999999

# %%
# to install pandas
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# rows from the start
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
# rows from the end
df.tail()
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
# random rows
df.sample(3)
# Out:
#                      title   industry  release_year  imdb_rating  \
# 27                      PK  Bollywood          2014          8.1
# 29       The Kashmir Files  Bollywood          2022          8.3
# 18  Avengers: Infinity War  Hollywood          2018          8.4
#
#                 studio  budget  revenue      unit currency language
# 27  Vinod Chopra Films   850.0   8540.0  Millions      INR    Hindi
# 29         Zee Studios   250.0   3409.0  Millions      INR    Hindi
# 18      Marvel Studios   400.0   2048.0  Millions      USD  English

# %%
# row 2 to 6 just like python list
df[2:7]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
# 6              Interstellar  Hollywood          2014          8.6
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 6      Warner Bros. Pictures   165.0    701.8  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df['imdb_rating']
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.0
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
# part of df only but a single column --> 1-dim data structure
type(df.imdb_rating)
# Out:
# pandas.Series

# %%
# Entire spreadsheet --> 2-dim table structure
type(df)
# Out:
# pandas.DataFrame

# %%
df['imdb_rating'].mean()
# Out:
# np.float64(7.919444444444445)

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df[df['industry'] == "Bollywood"]['imdb_rating'].mean()
# Out:
# np.float64(7.656250000000001)

# %%
df[df['industry'] == "Hollywood"]['imdb_rating'].mean()
# Out:
# np.float64(8.130000000000003)

# %%
df_h = df[df['industry'] == 'Hollywood']
df_b = df[df['industry'] == 'Bollywood']

# %%
df_h.imdb_rating.mean() , df_h.imdb_rating.max(), df_h.imdb_rating.min()
# Out:
# (np.float64(8.130000000000003), np.float64(9.3), np.float64(6.8))

# %%
df_b.imdb_rating.mean(), df_b.imdb_rating.max(), df_b.imdb_rating.min()
# Out:
# (np.float64(7.656250000000001), np.float64(8.4), np.float64(1.9))

# %%
df["industry"].unique()
# Out:
# <StringArray>
# ['Bollywood', 'Hollywood']
# Length: 2, dtype: str

# %%
print(df.language.unique())
print(df.language.value_counts().unique())
# Out:
# <StringArray>
# ['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu']
# Length: 5, dtype: str
# [20 12  3  1]

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
a = df[["title","imdb_rating","industry"]]
a.head()
# Out:
#                                          title  imdb_rating   industry
# 0                              Pather Panchali          8.3  Bollywood
# 1  Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                        Thor: The Dark World           6.8  Hollywood
# 3                              Thor: Ragnarok           7.9  Hollywood
# 4                      Thor: Love and Thunder           6.8  Hollywood

# %%
df.head()
df[(df.release_year >= 2000) & (df.release_year <= 2010) ]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
df[df["studio"] == "Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     str
#  1   industry      37 non-null     str
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     str
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     str
#  8   currency      37 non-null     str
#  9   language      37 non-null     str
# dtypes: float64(3), int64(1), str(6)
# memory usage: 3.0 KB

# %%
df[(df.imdb_rating == df.imdb_rating.max()) | (df.imdb_rating == df.imdb_rating.min())]['title']
# Out:
# 5     The Shawshank Redemption
# 31                      Race 3
# Name: title, dtype: str

# %%
import time

df['movie_age'] = df['release_year'].apply(lambda x: time.localtime().tm_year - x )
df['movie_age']
# Out:
# 0     71
# 1      4
# 2     13
# 3      9
# 4      4
# 5     32
# 6     12
# 7     20
# 8     26
# 9     29
# 10    80
# 11    17
# 12    54
# 13    18
# 14    33
# 15    33
# 16     7
# 17     7
# 18     8
# 19    15
# 20    12
# 21    31
# 22    17
# 23    25
# 24    11
# 25    19
# 26    23
# 27    12
# 28     8
# 29     4
# 30    11
# 31     8
# 32     5
# 33     4
# 34     5
# 35     4
# 36    11
# Name: movie_age, dtype: int64

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  movie_age
# 0      INR  Bengali         71
# 1      USD  English          4
# ...

# %%
df['profit'] = df['revenue'] - df['budget']
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  movie_age   profit
# 0      INR  Bengali         71  30000.0
# ...

# %%
df['profit'] = df.apply(lambda x : x['revenue'] - x['budget'], axis=1)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  movie_age   profit
# 0      INR  Bengali         71  30000.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index("title")
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# The Shawshank Redemption                     Hollywood          1994
# Interstellar                                 Hollywood          2014
# The Pursuit of Happyness                     Hollywood          2006
# Gladiator                                    Hollywood          2000
# Titanic                                      Hollywood          1997
# It's a Wonderful Life                        Hollywood          1946
# Avatar                                       Hollywood          2009
# ...

# %%
df.loc[0]
# Out:
# title                     Pather Panchali
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# movie_age                              71
# profit                            30000.0
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
#
#   currency language  movie_age   profit
# 0      INR  Bengali         71  30000.0
# 1      USD  English          4    754.8

# %%
df.iloc[2:10]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
# 6              Interstellar  Hollywood          2014          8.6
# 7  The Pursuit of Happyness  Hollywood          2006          8.0
# 8                 Gladiator  Hollywood          2000          8.5
# 9                   Titanic  Hollywood          1997          7.9
#
#                       studio  budget  revenue      unit currency language  \
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# ...
