# %%
# dictionary ---> mutable, key-value pairs, fast daya retrieval by key.

contacts = {
    'rachel':9922334477,
    'joey':8811224433,
    'monica':6655884433
    }
type(contacts)
# Out:
# dict

# %%
contacts
# Out:
# {'rachel': 9922334477, 'joey': 8811224433, 'monica': 6655884433}

# %%
contacts['rachel']
# Out:
# 9922334477

# %%
# Keys can be integers too.
dic = {
    1 : "apoorva",
    2 : "tanvi"
}
dic
# Out:
# {1: 'apoorva', 2: 'tanvi'}

# %%
contacts['phoebe']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 contacts['phoebe']
#
# KeyError: 'phoebe'

# %%
# this will return none if key not present. we can set default value to show also.
contacts.get('phoebe',-1)
# Out:
# -1

# %%
contacts.get("joey")
# Out:
# 8811224433

# %%
a = [x for x in contacts.keys()]
print(a)
b = [x for x in contacts.values()]
print(b)
# Out:
# ['rachel', 'joey', 'monica']
# [9922334477, 8811224433, 6655884433]

# %%
contacts['rachel'] = 9944223344
contacts['kratos'] = 0000000000
contacts
# Out:
# {'rachel': 9944223344, 'joey': 8811224433, 'monica': 6655884433, 'kratos': 0}

# %%
del contacts["joey"]
contacts
# Out:
# {'rachel': 9944223344, 'monica': 6655884433, 'kratos': 0}

# %%
"chandler" in contacts
# Out:
# False

# %%
info = {
    "rachel" : {"phone":3344334433, "age":29, "address":"1 blue st"},
    "phoebe" : {"phone":9944334433, "age":30, "address":"24 avenue st"},
    "monica" : {"phone":8844334433, "age":29, "address":"3 blue st"}
}

# %%
info["rachel"]["age"]
# Out:
# 29

# %%
for key,value in info.items():
    print(key, value)
# Out:
# rachel {'phone': 3344334433, 'age': 29, 'address': '1 blue st'}
# phoebe {'phone': 9944334433, 'age': 30, 'address': '24 avenue st'}
# monica {'phone': 8844334433, 'age': 29, 'address': '3 blue st'}

# %%
dir(contacts)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
